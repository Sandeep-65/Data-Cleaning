# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # New Section

# %%
ipl=pd.read_csv("/content/matches.csv")

# %%
ipl
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl['season']
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 631    2016
# 632    2016
# 633    2016
# 634    2016
# 635    2016
# Name: season, Length: 636, dtype: int64

# %%
ipl['city']
# Out:
# 0      Hyderabad
# 1           Pune
# 2         Rajkot
# 3         Indore
# 4      Bangalore
#          ...
# 631       Raipur
# 632    Bangalore
# 633        Delhi
# 634        Delhi
# 635    Bangalore
# Name: city, Length: 636, dtype: object

# %%
print("\nChecking for missing values using isnull():\n")
ipl.isnull()
ipl.head()
# Out:
# Checking for missing values using isnull():
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 631  False   False  False  False  False  False        False          False
# 632  False   False  False  False  False  False        False          False
# 633  False   False  False  False  False  False        False          False
# 634  False   False  False  False  False  False        False          False
# 635  False   False  False  False  False  False        False          False
#
# ...

# %%
ipl.notnull().head()
# Out:
#      id  season  city  date  team1  team2  toss_winner  toss_decision  result  \
# 0  True    True  True  True   True   True         True           True    True
# 1  True    True  True  True   True   True         True           True    True
# 2  True    True  True  True   True   True         True           True    True
# 3  True    True  True  True   True   True         True           True    True
# 4  True    True  True  True   True   True         True           True    True
#
#    dl_applied  winner  win_by_runs  win_by_wickets  player_of_match  venue  \
# 0        True    True         True            True             True   True
# 1        True    True         True            True             True   True
# 2        True    True         True            True             True   True
# 3        True    True         True            True             True   True
# 4        True    True         True            True             True   True
#
#    umpire1  umpire2  umpire3
# ...

# %%
ipl.dropna()
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
ipl.fillna(True)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl.replace(None)
# Out:
# <ipython-input-22-8ecb6696a921>:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   ipl.replace(None)
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# ...

# %%
ipl.astype(str)
# Out:
#       id season       city        date                        team1  \
# 0      1   2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2   2017       Pune  2017-04-06               Mumbai Indians
# 2      3   2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4   2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5   2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...    ...        ...         ...                          ...
# 631  632   2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633   2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634   2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635   2016      Delhi  2016-05-27                Gujarat Lions
# 635  636   2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl.dropna(axis=1)
# Out:
#       id  season        date                        team1  \
# 0      1    2017  2017-04-05          Sunrisers Hyderabad
# 1      2    2017  2017-04-06               Mumbai Indians
# 2      3    2017  2017-04-07                Gujarat Lions
# 3      4    2017  2017-04-08       Rising Pune Supergiant
# 4      5    2017  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...         ...                          ...
# 631  632    2016  2016-05-22             Delhi Daredevils
# 632  633    2016  2016-05-24                Gujarat Lions
# 633  634    2016  2016-05-25          Sunrisers Hyderabad
# 634  635    2016  2016-05-27                Gujarat Lions
# 635  636    2016  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
ipl.loc[3:6]
# Out:
#    id  season       city        date                        team1  \
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
#
#                  team2                  toss_winner toss_decision  result  \
# 3      Kings XI Punjab              Kings XI Punjab         field  normal
# 4     Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 5  Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 6       Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 3           0              Kings XI Punjab            0               6
# 4           0  Royal Challengers Bangalore           15               0
# ...

# %%
ipl.set_index(['win_by_runs','id'])
# Out:
#                  season       city        date                        team1  \
# win_by_runs id
# 35          1      2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 0           2      2017       Pune  2017-04-06               Mumbai Indians
#             3      2017     Rajkot  2017-04-07                Gujarat Lions
#             4      2017     Indore  2017-04-08       Rising Pune Supergiant
# 15          5      2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ...                 ...        ...         ...                          ...
# 0           632    2016     Raipur  2016-05-22             Delhi Daredevils
#             633    2016  Bangalore  2016-05-24                Gujarat Lions
# 22          634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 0           635    2016      Delhi  2016-05-27                Gujarat Lions
# 8           636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
# ...

# %%
ipl.reset_index()
# Out:
#      index   id  season       city        date                        team1  \
# 0        0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        1    2    2017       Pune  2017-04-06               Mumbai Indians
# 2        2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3        3    4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4        4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...  ...     ...        ...         ...                          ...
# 631    631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632    632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633    633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634    634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635    635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
# ...

# %%
ipl.loc[::2]
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 626  627    2016         Kanpur  2016-05-19        Kolkata Knight Riders
# 628  629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 630  631    2016        Kolkata  2016-05-22        Kolkata Knight Riders
# 632  633    2016      Bangalore  2016-05-24                Gujarat Lions
# 634  635    2016          Delhi  2016-05-27                Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl.loc[155,'season']
# Out:
# 2009

# %%
ipl.iloc[[2]]
# Out:
#    id  season    city        date          team1                  team2  \
# 2   3    2017  Rajkot  2017-04-07  Gujarat Lions  Kolkata Knight Riders
#
#              toss_winner toss_decision  result  dl_applied  \
# 2  Kolkata Knight Riders         field  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 2  Kolkata Knight Riders            0              10         CA Lynn
#
#                                     venue      umpire1    umpire2  umpire3
# 2  Saurashtra Cricket Association Stadium  Nitin Menon  CK Nandan      NaN

# %%
ipl.iloc[lambda k : k.index%2==0]
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 626  627    2016         Kanpur  2016-05-19        Kolkata Knight Riders
# 628  629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 630  631    2016        Kolkata  2016-05-22        Kolkata Knight Riders
# 632  633    2016      Bangalore  2016-05-24                Gujarat Lions
# 634  635    2016          Delhi  2016-05-27                Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# **Groping & aggregation**

# %%
df=pd.read_csv('/content/Students.csv')

# %%
df
# Out:
#          Name    Grade  Age  Gender  Score
# 0    Student1  Grade 8   14    Male     85
# 1    Student2  Grade 7   13  Female     92
# 2    Student3  Grade 9   15    Male     78
# 3    Student4  Grade 6   12  Female     95
# 4    Student5  Grade 8   14    Male     89
# 5    Student6  Grade 7   13  Female     88
# 6    Student7  Grade 9   15    Male     76
# 7    Student8  Grade 6   12  Female     94
# 8    Student9  Grade 8   14    Male     87
# 9   Student10  Grade 7   13  Female     91
# 10  Student11  Grade 9   15    Male     75
# 11  Student12  Grade 6   12  Female     96
# 12  Student13  Grade 8   14    Male     88
# 13  Student14  Grade 7   13  Female     90
# 14  Student15  Grade 9   15    Male     77
# 15  Student16  Grade 6   12  Female     93
# 16  Student17  Grade 8   14    Male     86
# 17  Student18  Grade 7   13  Female     89
# 18  Student19  Grade 9   15    Male     74
# 19  Student20  Grade 6   12  Female     97

# %%
student=df.groupby('Grade+')

# %%
student

# %%
student.groups
# Out:
# {'Grade 6': [3, 7, 11, 15, 19], 'Grade 7': [1, 5, 9, 13, 17], 'Grade 8': [0, 4, 8, 12, 16], 'Grade 9': [2, 6, 10, 14, 18]}

# %%
for name,group in student:
  print(f"Group name:{name}")
  print(group)
# Out:
# Group name:Grade 6
#          Name    Grade  Age  Gender  Score
# 3    Student4  Grade 6   12  Female     95
# 7    Student8  Grade 6   12  Female     94
# 11  Student12  Grade 6   12  Female     96
# 15  Student16  Grade 6   12  Female     93
# 19  Student20  Grade 6   12  Female     97
# Group name:Grade 7
#          Name    Grade  Age  Gender  Score
# 1    Student2  Grade 7   13  Female     92
# 5    Student6  Grade 7   13  Female     88
# 9   Student10  Grade 7   13  Female     91
# 13  Student14  Grade 7   13  Female     90
# 17  Student18  Grade 7   13  Female     89
# Group name:Grade 8
#          Name    Grade  Age Gender  Score
# 0    Student1  Grade 8   14   Male     85
# 4    Student5  Grade 8   14   Male     89
# 8    Student9  Grade 8   14   Male     87
# 12  Student13  Grade 8   14   Male     88
# 16  Student17  Grade 8   14   Male     86
# Group name:Grade 9
#          Name    Grade  Age Gender  Score
# 2    Student3  Grade 9   15   Male     78
# ...

# %%
student.get_group('Grade 9')
# Out:
#          Name    Grade  Age Gender  Score
# 2    Student3  Grade 9   15   Male     78
# 6    Student7  Grade 9   15   Male     76
# 10  Student11  Grade 9   15   Male     75
# 14  Student15  Grade 9   15   Male     77
# 18  Student19  Grade 9   15   Male     74

# %%
df['Grade'].value_counts()
# Out:
# Grade
# Grade 8    5
# Grade 7    5
# Grade 9    5
# Grade 6    5
# Name: count, dtype: int64

# %%
k=df[df['Grade']=="Garde9"]

# %%
k
# Out:
# Empty DataFrame
# Columns: [Name, Grade, Age, Gender, Score]
# Index: []

# %%
k[k['Score']==k['Score'].max()]['Name']
# Out:
# Series([], Name: Name, dtype: object)
